# %%
a = input()

b = input()

print(a , b)

c = a+b

print(c)
# Out:
# 5
# 6
# 5 6
# 56

# %%
a = int (input())

b = int (input())

print(a) , (b)

c = a+b

print(c)
# Out:
# 5
# 6
# 5
# 11

# %%
#7

a = int (input())

b = int (input())

div = a/b
fdiv = int(a/b)
exp = a**b

print(div, '\n', fdiv, '\n' , exp)
# Out:
# 8
# 3
# 2.6666666666666665
#  2
#  512

# %%
#8
a = int (input())
b = int (input())

test = a==b

print(test)
# Out:
# 24
# 5
# False

# %%
#9

a = 5
b = 3

print("before: \na:", a, "b:" , b)

a, b = b, a

print("after:", a, "\nb:" , b)
# Out:
# before:
# a: 5 b: 3
# after: 3
# b: 5

# %%
#11

length = float (input("enter the length:"))
width = float (input("enter the width:"))

area = length * width

print(f"the area is:, {area:.3f}.,")
# Out:
# enter the length:5.666
# enter the width:4.777
# the area is:, 27.066.,

# %%
length = float (input("enter the length:"))
width = float (input("enter the width:"))

area = length * width

print(f"the area of the rectangle is: {area:.3f}.")
# Out:
# enter the length:6.777
# enter the width:7.888
# the area of the rectangle is: 53.457.

# %%
#12
r = float (input("enter the radius:"))
pi = 3.1416
area =2*pi*r
print (area)
# Out:
# enter the radius:4
# 25.1328

# %%
#13

C = float(input("Enter temperature: "))

print(f"The temperature in fahrenheit:{(C*9/5) + 32} ")
# Out:
# Enter temperature: 75
# The temperature in fahrenheit:167.0

# %%
#14

n = int(input("per day comsumption:"))

print(f"total number of cigarettes smoked in a year: {365*n}")
# Out:
# per day comsumption:2
# total number of cigarettes smoked in a year: 730
