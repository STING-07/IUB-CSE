# %%
a = int(input("Enter a number 1: "))
b = int(input("Enter a number 2: "))

c = a + b

print(c)
# Out:
# Enter a number 1: 10
# Enter a number 2: 5
# 15

# %%
m = int(input("Enter slope: "))
b = int(input("Enter intercept: "))
x = int(input("Enter x: "))

y = (m*x+b)

print("f(x)","=",y)
# Out:
# Enter slope: 5
# Enter intercept: 6
# Enter x: 3
# f(x) = 21

# %%
x1 = int(input)
y1 = int(input)

x2 = int(input)
y2 = int(input)

print("x,y="{(x2-x1)**0.5(y2-y1)**0.5})
# Out:
#   File "/tmp/ipython-input-2-1874143209.py", line 7
#     print("x,y="{(x2-x1)**0.5(y2-y1)**0.5})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
